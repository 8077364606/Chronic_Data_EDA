# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/kidney_disease.csv")
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 395  ...   47  6700  4.9   no  no   no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# 397  ...   49  6600  5.4   no  no   no  good  no  no         notckd
# 398  ...   51  7200  5.9   no  no   no  good  no  no         notckd
# 399  ...   53  6800  6.1   no  no   no  good  no  no         notckd
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df["id"]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 395    395
# 396    396
# 397    397
# 398    398
# 399    399
# Name: id, Length: 400, dtype: int64

# %%
df.drop("id",inplace = True,axis =1)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df.describe()
# Out:
#               age  blood_pressure  specific_gravity     albumin       sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        blood_glucose_random  blood_urea  serum_creatinine      sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume          object
# white_blood_cell_count      object
# red_blood_cell_count        object
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                          9
# blood_pressure              12
# specific_gravity            47
# albumin                     46
# sugar                       49
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# sodium                      87
# potassium                   88
# haemoglobin                 52
# packed_cell_volume          70
# white_blood_cell_count     105
# red_blood_cell_count       130
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# class                        0
# dtype: int64

# %%
df["packed_cell_volume"].isnull().sum()
# Out:
# 70

# %%
df["packed_cell_volume"].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df["packed_cell_volume"].dtype #now it's in object datatype
# Out:
# dtype('O')

# %%
df["packed_cell_volume"] = pd.to_numeric(df["packed_cell_volume"],errors ="coerce" )

# %%
df["packed_cell_volume"].dtype #changed into the 'float' datatype
# Out:
# dtype('float64')

# %%
df['white_blood_cell_count'].dtype#now it's in object datatype
# Out:
# dtype('O')

# %%
df["white_blood_cell_count"] = pd.to_numeric(df["white_blood_cell_count"],errors ="coerce" )

# %%
df["white_blood_cell_count"].dtype #changed into the 'float' datatype
# Out:
# dtype('float64')

# %%
df["red_blood_cell_count"].dtype #now it's in object datatype
# Out:
# dtype('O')

# %%
df["red_blood_cell_count"] = pd.to_numeric(df["red_blood_cell_count"],errors ="coerce" )

# %%
df["red_blood_cell_count"].dtype #changed into the 'float' datatype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
cat_cols = [col  for col in df.columns if df[col].dtype == "object"]
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
num_cols = [col  for col in df.columns if df[col].dtype != "object"]
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
for col in cat_cols:
  print(f"{col} , has unique {df[col].unique()} values \n")
# Out:
# red_blood_cells , has unique [nan 'normal' 'abnormal'] values
#
# pus_cell , has unique ['normal' 'abnormal' nan] values
#
# pus_cell_clumps , has unique ['notpresent' 'present' nan] values
#
# bacteria , has unique ['notpresent' 'present' nan] values
#
# hypertension , has unique ['yes' 'no' nan] values
#
# diabetes_mellitus , has unique ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease , has unique ['no' 'yes' '\tno' nan] values
#
# appetite , has unique ['good' 'poor' nan] values
#
# peda_edema , has unique ['no' 'yes' nan] values
#
# aanemia , has unique ['no' 'yes' nan] values
#
# class , has unique ['ckd' 'ckd\t' 'notckd'] values

# %%
df.diabetes_mellitus.unique()
# Out:
# array(['yes', 'no', ' yes', '\tno', '\tyes', nan], dtype=object)

# %%
df['diabetes_mellitus'] = df['diabetes_mellitus'].replace(to_replace={"\tno":"no","\tyes":"yes"," yes":'yes'})
df["diabetes_mellitus"]
# Out:
# 0      yes
# 1       no
# 2      yes
# 3       no
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: diabetes_mellitus, Length: 400, dtype: object

# %%
df.diabetes_mellitus.unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df.coronary_artery_disease.unique()
# Out:
# array(['no', 'yes', '\tno', nan], dtype=object)

# %%
df["coronary_artery_disease"] = df['coronary_artery_disease'].replace("\tno","no")
df["coronary_artery_disease"]
# Out:
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no
#        ..
# 395    no
# 396    no
# 397    no
# 398    no
# 399    no
# Name: coronary_artery_disease, Length: 400, dtype: object

# %%
df.coronary_artery_disease.unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
df["class"] = df['class'].replace("ckd\t",'ckd')
df['class']
# Out:
# 0         ckd
# 1         ckd
# 2         ckd
# 3         ckd
# 4         ckd
#         ...
# 395    notckd
# 396    notckd
# 397    notckd
# 398    notckd
# 399    notckd
# Name: class, Length: 400, dtype: object

# %%
df["class"].unique()
# Out:
# array(['ckd', 'notckd'], dtype=object)

# %%
for col in cat_cols:
  print(f"{col} , has unique {df[col].unique()} values \n")
# Out:
# red_blood_cells , has unique [nan 'normal' 'abnormal'] values
#
# pus_cell , has unique ['normal' 'abnormal' nan] values
#
# pus_cell_clumps , has unique ['notpresent' 'present' nan] values
#
# bacteria , has unique ['notpresent' 'present' nan] values
#
# hypertension , has unique ['yes' 'no' nan] values
#
# diabetes_mellitus , has unique ['yes' 'no' nan] values
#
# coronary_artery_disease , has unique ['no' 'yes' nan] values
#
# appetite , has unique ['good' 'poor' nan] values
#
# peda_edema , has unique ['no' 'yes' nan] values
#
# aanemia , has unique ['no' 'yes' nan] values
#
# class , has unique ['ckd' 'notckd'] values

# %%
#visualization

plt.figure(figsize=(15,8))
sns.histplot(df["age"].dropna(),bins = 20,kde = True ,color = "skyblue")
plt.title("ditribution of age")
plt.xlabel("age")
plt.ylabel("frequency")

plt.show()

# %%
#insights>>
# the distribution of age is right skewed
# the  median is more like than mean

# %%
sns.countplot(x="red_blood_cells",data=df,color="skyblue")
# Out:
# <Axes: xlabel='red_blood_cells', ylabel='count'>

# %%
sns.countplot(x="hypertension",data=df,color="skyblue")
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
sns.countplot(x = "coronary_artery_disease",data = df,color = "skyblue")
# Out:
# <Axes: xlabel='coronary_artery_disease', ylabel='count'>

# %%
sns.boxplot(x = "class",y = "blood_urea",data=df,palette="viridis")
plt.title("Boxplot")
plt.xlabel("Class")
plt.ylabel("Blood_urea_values")
plt.show()

# %%
#insights>>
#class ckd have outliers
#blood_urea is higher for chronic desease
#median is 50

# %%
sns.violinplot(x = "class",y = "blood_urea",data=df,palette="viridis")
plt.title("Boxplot")
plt.xlabel("Class")
plt.ylabel("Blood_urea_values")
plt.show()

# %%
sns.violinplot(x = "class",y = "serum_creatinine",data=df,palette="coolwarm")
# Out:
# <Axes: xlabel='class', ylabel='serum_creatinine'>

# %%
df.appetite.value_counts()
# Out:
# appetite
# good    317
# poor     82
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
df['appetite'].value_counts().plot.pie(autopct = "%1.1f%%",explode=[0,0.1],shadow = True)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df["white_blood_cell_count"].dropna(),kde = True,palette= "coolwarm")
# Out:
# <Axes: xlabel='white_blood_cell_count', ylabel='Count'>

# %%
sns.histplot(df["red_blood_cell_count"].dropna(),kde = True,palette= "coolwarm")
# Out:
# <Axes: xlabel='red_blood_cell_count', ylabel='Count'>

# %%
df["diabetes_mellitus"].value_counts()
# Out:
# diabetes_mellitus
# no     261
# yes    137
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
df['diabetes_mellitus'].value_counts().plot.pie(autopct = "%1.1f%%",wedgeprops = dict(width=0.7),explode=[0,0.1],shadow = True)
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(x = df["age"],y = df["blood_pressure"],data=df)
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
#bivariant Visualization
plt.figure(figsize=(15,8))
sns.scatterplot(x = df["age"],y = df["blood_pressure"],hue = "class", data =df,palette = "coolwarm")
plt.show()

# %%
#insights>>
#blood pressure increasing as age is increasing

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = df["age"],y = df["sugar"], data =df,palette = "coolwarm")
plt.show()

# %%
#insights>>
#sugar is increasing as age is increasing

# %%
sns.boxplot(x='diabetes_mellitus',y="albumin",data=df,palette = "viridis")
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
sns.violinplot(x='diabetes_mellitus',y="albumin",data=df,palette = "coolwarm")
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
sns.barplot(x="diabetes_mellitus",y="blood_pressure",data=df,color="skyblue")
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='blood_pressure'>

# %%
diabetes_hypertension = pd.crosstab(df["diabetes_mellitus"],df["hypertension"])
diabetes_hypertension
# Out:
# hypertension        no  yes
# diabetes_mellitus
# no                 220   41
# yes                 31  106

# %%
diabetes_hypertension.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='diabetes_mellitus'>

# %%
cols = ['age', 'blood_pressure', 'blood_glucose_random', 'serum_creatinine', 'class']
g = sns.PairGrid(df[cols],hue = "class",palette="coolwarm")
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.boxplot)
plt.title("pair grid for selected columns")
plt.show()

# %%
sns.pairplot(df[cols],hue="class",palette="husl")

# %%
df.corr(numeric_only=True)
# Out:
#                              age  blood_pressure  specific_gravity   albumin  \
# age                     1.000000        0.159480         -0.191096  0.122091
# blood_pressure          0.159480        1.000000         -0.218836  0.160689
# specific_gravity       -0.191096       -0.218836          1.000000 -0.469760
# albumin                 0.122091        0.160689         -0.469760  1.000000
# sugar                   0.220866        0.222576         -0.296234  0.269305
# blood_glucose_random    0.244992        0.160193         -0.374710  0.379464
# blood_urea              0.196985        0.188517         -0.314295  0.453528
# serum_creatinine        0.132531        0.146222         -0.361473  0.399198
# sodium                 -0.100046       -0.116422          0.412190 -0.459896
# potassium               0.058377        0.075151         -0.072787  0.129038
# haemoglobin            -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
corr= df.corr(numeric_only = True)
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True,cmap = "coolwarm",linewidth = .5)
plt.show()

# %%
sns.swarmplot(x="diabetes_mellitus",y="age",data = df, hue = "coronary_artery_disease",palette = "husl")
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='age'>

# %%
fig = px.scatter(df,x="age",y="blood_pressure",color ="class",hover_data=['serum_creatinine', 'haemoglobin'],title = "interactive scatterplot with hover information")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df,x="age",y="blood_urea",z="blood_pressure",color="class")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df, x = 'age', y = 'blood_pressure',z = 'serum_creatinine', color = 'coronary_artery_disease', title = "3d scatter plot scatterplot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df, x='age', y='blood_pressure', z='serum_creatinine', color='haemoglobin',
                    title='3D Scatter plot with Color Gradient')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
corr_data = df.corr(numeric_only = True)
corr_data
# Out:
#                              age  blood_pressure  specific_gravity   albumin  \
# age                     1.000000        0.159480         -0.191096  0.122091
# blood_pressure          0.159480        1.000000         -0.218836  0.160689
# specific_gravity       -0.191096       -0.218836          1.000000 -0.469760
# albumin                 0.122091        0.160689         -0.469760  1.000000
# sugar                   0.220866        0.222576         -0.296234  0.269305
# blood_glucose_random    0.244992        0.160193         -0.374710  0.379464
# blood_urea              0.196985        0.188517         -0.314295  0.453528
# serum_creatinine        0.132531        0.146222         -0.361473  0.399198
# sodium                 -0.100046       -0.116422          0.412190 -0.459896
# potassium               0.058377        0.075151         -0.072787  0.129038
# haemoglobin            -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Heatmap(z=corr_data.values,y=corr_data.index , x=corr_data.columns))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
  df[num_cols].isnull().sum()
# Out:
# age                         9
# blood_pressure             12
# specific_gravity           47
# albumin                    46
# sugar                      49
# blood_glucose_random       44
# blood_urea                 19
# serum_creatinine           17
# sodium                     87
# potassium                  88
# haemoglobin                52
# packed_cell_volume         71
# white_blood_cell_count    106
# red_blood_cell_count      131
# dtype: int64

# %%
df[num_cols]=df[num_cols].fillna(df[num_cols].median())

# %%
df[num_cols].isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specific_gravity          0
# albumin                   0
# sugar                     0
# blood_glucose_random      0
# blood_urea                0
# serum_creatinine          0
# sodium                    0
# potassium                 0
# haemoglobin               0
# packed_cell_volume        0
# white_blood_cell_count    0
# red_blood_cell_count      0
# dtype: int64

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
df[cat_cols].isnull().sum()
# Out:
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# class                        0
# dtype: int64

# %%
mode_values = df.mode().iloc[0]
mode_values
# Out:
# age                              55.0
# blood_pressure                   80.0
# specific_gravity                 1.02
# albumin                           0.0
# sugar                             0.0
# red_blood_cells                normal
# pus_cell                       normal
# pus_cell_clumps            notpresent
# bacteria                   notpresent
# blood_glucose_random            121.0
# blood_urea                       42.0
# serum_creatinine                  1.2
# sodium                          138.0
# potassium                         4.4
# haemoglobin                     12.65
# packed_cell_volume               40.0
# white_blood_cell_count         8000.0
# red_blood_cell_count              4.8
# hypertension                       no
# diabetes_mellitus                  no
# coronary_artery_disease            no
# appetite                         good
# peda_edema                         no
# aanemia                            no
# class                             ckd
# ...

# %%
df[cat_cols]= df[cat_cols].fillna(mode_values)
df[cat_cols].isnull().sum()
# Out:
# red_blood_cells            0
# pus_cell                   0
# pus_cell_clumps            0
# bacteria                   0
# hypertension               0
# diabetes_mellitus          0
# coronary_artery_disease    0
# appetite                   0
# peda_edema                 0
# aanemia                    0
# class                      0
# dtype: int64

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
#encoding

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
for col in cat_cols:
  df[col] = labelencoder.fit_transform(df[col])

df.head() #categorical column cahnged into the numeric column
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0                1
# 1   7.0            50.0             1.020      4.0    0.0                1
# 2  62.0            80.0             1.010      2.0    3.0                1
# 3  48.0            70.0             1.005      4.0    0.0                1
# 4  51.0            80.0             1.010      2.0    0.0                1
#
#    pus_cell  pus_cell_clumps  bacteria  blood_glucose_random  ...  \
# 0         1                0         0                 121.0  ...
# 1         1                0         0                 121.0  ...
# 2         1                0         0                 423.0  ...
# 3         0                1         0                 117.0  ...
# 4         1                0         0                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells              int64
# pus_cell                     int64
# pus_cell_clumps              int64
# bacteria                     int64
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                 int64
# diabetes_mellitus            int64
# coronary_artery_disease      int64
# appetite                     int64
# peda_edema                   int64
# aanemia                      int64
# class                        int64
# dtype: object

# %%
X = df.drop("class",axis=1)
y = df["class"]

# %%
#Train-test split and / ML model training
